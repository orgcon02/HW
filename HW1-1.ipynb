# %% [markdown]
# # Heading

# %%
import pandas as pd

# %%
url = "http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange=NASDAQ&render=download"

# %%
df= pd.read_csv(url)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Symbol                                    Name LastSale     MarketCap  \
# 0       PIH  1347 Property Insurance Holdings, Inc.      7.2  4.288872e+07
# 1      TURN                180 Degree Capital Corp.     1.89  5.881975e+07
# 2      FLWS                 1-800 FLOWERS.COM, Inc.     9.25  6.001301e+08
# 3      FCCY           1st Constitution Bancorp (NJ)    18.25  1.472642e+08
# 4      SRCE                  1st Source Corporation    51.92  1.346604e+09
# 5      VNET                    21Vianet Group, Inc.     7.53  4.494795e+08
# 6      TWOU                                2U, Inc.    61.96  3.220742e+09
# 7      JOBS                             51job, Inc.    61.72  1.653687e+09
# 8      CAFD              8point3 Energy Partners LP    15.21  1.202882e+09
# 9      EGHT                                 8x8 Inc     12.5  1.147859e+09
# 10     AVHI                         A V Homes, Inc.    16.95  3.806239e+08
# ...
